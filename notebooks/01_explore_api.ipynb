# %% [markdown]
# # Explore BrightSky API
#
# Let's explore the weather API before building the pipeline.

# %%
import requests
import pandas as pd

API_URL = "https://api.brightsky.dev"

# %%
# TODO: Explore the API
# 1. Check available endpoints
# 2. Get weather data for Berlin
# 3. Look at data structure
